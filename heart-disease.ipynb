# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# heart = pd.read_csv("../input/heart-disease-dataset/heart.csv") --> This code Used on Kaggle
heart=pd.read_csv("heart.csv")

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
heart.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# Data Analysis

# %%
heart.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
sns.lmplot(x= "age", y = "sex",data = heart, hue = "target")

# %%
heart.hist(bins = 70, grid = False, figsize=(20,15));

# %%
questions = ["1. How many people have heart disease and how many people doesn't have heart disease? ", 
             "2. People of which sex has most heart disease?",
             "3. People of which sex has which type of chest pain most?",
             "4. People with which chest pain are most pron to have heart disease?",
             "5. Age vs Maximum heart rate when people have heart disease.",
             "6. Age vs Maximum heart rate when people doesn't have heart disease.",
             "7. Age vs serum cholestoral when people have heart disease.",
             "8 Age vs serum cholestoral when people doesn't have heart disease.",
             "9. People of which sex has more exercise induced angina?",
             "10. Which sex of people has more fasting blood sugar > 120 mg/dl?"
            ]

# %%
questions[0]
# Out:
# "1. How many people have heart disease and how many people doesn't have heart disease? "

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart.target.value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
diases = heart.target.value_counts()

# %%
diases.plot(kind ='bar',color=["green","red"] , figsize = (20,15))
plt.title("Heart Disease Values")
plt.xlabel("1 = Heart Disease  , 0 =  No Heart Disease")
plt.ylabel("Amount");

# %%
diases.plot(kind = "pie", figsize = (10,10))
plt.title("Heart Disease Pie Chart")
plt.legend(["Disease","No Disease"]);

# %%
questions[1]
# Out:
# '2. People of which sex has most heart disease?'

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
heart.value_counts("sex")
# Out:
# sex
# 1    713
# 0    312
# dtype: int64

# %%
sex_disease = heart.value_counts("sex")
sex_disease
# Out:
# sex
# 1    713
# 0    312
# dtype: int64

# %%
sex_disease.plot(kind="bar",grid = False, color=("Green","Red"))
plt.title("Sex Disease Counts")
plt.xlabel("Disease")
plt.ylabel("Amounts");

# %%
sex_disease.plot(kind="pie", figsize=(10,10))
plt.legend(["Disease","No Disease"]);

# %%
pd.crosstab(heart.sex,heart.target)
# Out:
# target    0    1
# sex
# 0        86  226
# 1       413  300

# %%
sns.countplot(x = "target", data =  heart, hue = "sex");

# %%
questions[2]
# Out:
# '3. People of which sex has which type of chest pain most?'

# %%
cp_sex = heart.cp.value_counts()
cp_sex
# Out:
# 0    497
# 2    284
# 1    167
# 3     77
# Name: cp, dtype: int64

# %%
cp_sex.plot(kind='bar',color = ['green','springgreen','red','khaki'])
plt.title("Chest pain vs number of people");

# %%
pd.crosstab(heart.sex, heart.cp)
# Out:
# cp     0    1    2   3
# sex
# 0    133   57  109  13
# 1    364  110  175  64

# %%
pd.crosstab(heart.sex, heart.cp).plot(kind='bar',color = ['red','springgreen','green','khaki'])
plt.title('types of chest pain w.r.t sex')
plt.xlabel('0  = Female, 1 = Male');

# %%
questions[3]
# Out:
# '4. People with which chest pain are most pron to have heart disease?'

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
pd.crosstab(heart.cp, heart.target)
# Out:
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
sns.countplot(x = 'cp',data=heart,hue = 'target')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
questions[4],questions[5]
# Out:
# ('5. Age vs Maximum heart rate when people have heart disease.',
#  "6. Age vs Maximum heart rate when people doesn't have heart disease.")

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
sns.displot(x='age',data=heart,bins=50,kde=True);

# %%
plt.figure(figsize=(10,5))
plt.scatter(heart.age[heart.target==1],
           heart.thalach[heart.target ==1],
            color = 'tomato')
plt.scatter(heart.age[heart.target==0],
           heart.thalach[heart.target==0],
           c='lightgreen')
plt.title("Max Heart Rate vs Age")
plt.xlabel("Age")
plt.ylabel('Max Heart Rate')
plt.legend(["Diseas", "No disease"]);

# %%
questions[6],questions[7]
# Out:
# ('7. Age vs serum cholestoral when people have heart disease.',
#  "8 Age vs serum cholestoral when people doesn't have heart disease.")

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
sns.displot(x='age',data=heart,bins=70,kde=True);

# %%
plt.figure(figsize=(10,5))
plt.scatter(heart.age[heart.target==1],
           heart.chol[heart.target==1],
           c = 'Tomato')
plt.scatter(heart.age[heart.target==0],
           heart.chol[heart.target==0],
           c = 'Lightgreen')
plt.title('Age vs Max Serum Cholestoral Rate')
plt.xlabel('Age')
plt.ylabel("Serum Cholestoral")
plt.legend(['Disease','No Disease'])

# %%
questions[8]
# Out:
# '9. People of which sex has more exercise induced angina?'

# %%
heart.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
sns.countplot(x='exang',data = heart,hue='sex')
plt.title('Exercise Induced Angina with Respect To sex')
# Out:
# Text(0.5, 1.0, 'Exercise Induced Angina with Respect To sex')

# %%
heart[(heart['sex']==0) & (heart['exang']==0)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 4      62    0   0       138   294    1        1      106      0      1.9
# 5      58    0   0       100   248    0        0      122      0      1.0
# 10     71    0   0       112   149    0        1      125      0      1.6
# 12     34    0   1       118   210    0        1      192      0      0.7
# 15     34    0   1       118   210    0        1      192      0      0.7
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 989    71    0   1       160   302    0        1      162      0      0.4
# 992    50    0   0       110   254    0        0      159      0      0.0
# 1004   51    0   2       140   308    0        0      142      0      1.5
# 1014   44    0   2       108   141    0        1      175      0      0.6
# 1023   50    0   0       110   254    0        0      159      0      0.0
#
#       slope  ca  thal  target
# 4         1   3     2       0
# ...

# %%
heart[(heart['sex']==0) & (heart['exang']==1)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 11     43    0   0       132   341    1        0      136      1      3.0
# 25     61    0   0       145   307    0        0      146      1      1.0
# 29     55    0   0       180   327    0        2      117      1      3.4
# 47     66    0   0       178   228    1        1      165      1      1.0
# 51     57    0   0       140   241    0        1      123      1      0.2
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 963    57    0   0       140   241    0        1      123      1      0.2
# 976    63    0   0       108   269    0        1      169      1      1.8
# 986    55    0   0       180   327    0        2      117      1      3.4
# 996    56    0   0       134   409    0        0      150      1      1.9
# 1005   55    0   0       128   205    0        2      130      1      2.0
#
#       slope  ca  thal  target
# 11        1   0     3       0
# ...

# %%
print("Sex=Female(0) exercise againa=Yes(1) value is 74.\nSex=Female(0) exercise againa=No(0) value is 238.")
# Out:
# Sex=Female(0) exercise againa=Yes(1) value is 74.
# Sex=Female(0) exercise againa=No(0) value is 238.

# %%
heart[(heart['sex']==1) & (heart['exang']==0)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 3      61    1   0       148   203    0        1      161      0      0.0
# 6      58    1   0       114   318    0        2      140      0      4.4
# 8      46    1   0       120   249    0        0      144      0      0.8
# 19     58    1   2       140   211    1        0      165      0      0.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1013   58    1   0       114   318    0        2      140      0      4.4
# 1016   65    1   3       138   282    1        0      174      0      1.4
# 1018   41    1   0       110   172    0        0      158      0      0.0
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
heart[(heart['sex']==1) & (heart['exang']==1)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 7      55    1   0       160   289    0        0      145      1      0.8
# 9      54    1   0       122   286    0        0      116      1      3.2
# 13     51    1   0       140   298    0        1      122      1      4.2
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1015   58    1   0       128   216    0        0      131      1      2.2
# 1017   53    1   0       123   282    0        1       95      1      2.0
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
#
#       slope  ca  thal  target
# 1         0   0     3       0
# ...

# %%
print("Sex=Male(1) Exercise againa=Yes(1) value is 271 \nAnd Sex=Male(1) Exercise Againa No value is 442.")
# Out:
# Sex=Male(1) Exercise againa=Yes(1) value is 271
# And Sex=Male(1) Exercise Againa No value is 442.

# %%
questions[9]
# Out:
# '10. Which sex of people has more fasting blood sugar > 120 mg/dl?'

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
sns.countplot(x='fbs',data = heart,hue='sex')
plt.title('Blood Suger with Respect To sex');

# %%
heart[(heart['sex']==0) & (heart['fbs']==0)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 5      58    0   0       100   248    0        0      122      0      1.0
# 10     71    0   0       112   149    0        1      125      0      1.6
# 12     34    0   1       118   210    0        1      192      0      0.7
# 15     34    0   1       118   210    0        1      192      0      0.7
# 16     51    0   2       140   308    0        0      142      0      1.5
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 996    56    0   0       134   409    0        0      150      1      1.9
# 1004   51    0   2       140   308    0        0      142      0      1.5
# 1005   55    0   0       128   205    0        2      130      1      2.0
# 1014   44    0   2       108   141    0        1      175      0      0.6
# 1023   50    0   0       110   254    0        0      159      0      0.0
#
#       slope  ca  thal  target
# 5         1   0     2       1
# ...

# %%
heart[(heart['sex']==0) & (heart['fbs']==1)]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 4     62    0   0       138   294    1        1      106      0      1.9
# 11    43    0   0       132   341    1        0      136      1      3.0
# 27    58    0   1       136   319    1        0      152      0      0.0
# 47    66    0   0       178   228    1        1      165      1      1.0
# 50    58    0   3       150   283    1        0      162      0      1.0
# 123   65    0   2       140   417    1        0      157      0      0.8
# 135   58    0   0       170   225    1        0      146      1      2.8
# 175   56    0   0       200   288    1        0      133      1      4.0
# 229   66    0   0       178   228    1        1      165      1      1.0
# 240   54    0   1       132   288    1        0      159      1      0.0
# 264   58    0   0       170   225    1        0      146      1      2.8
# 269   71    0   2       110   265    1        0      130      0      0.0
# ...

# %%
print('Sex=Female(0) Blood Suger no(0) value is 270, \nSex=Female(0) Blood Suger Yes(1) value is 41')
# Out:
# Sex=Female(0) Blood Suger no(0) value is 270,
# Sex=Female(0) Blood Suger Yes(1) value is 41

# %%
heart[(heart['sex']==1) & (heart['fbs']==0)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 6      58    1   0       114   318    0        2      140      0      4.4
# 7      55    1   0       160   289    0        0      145      1      0.8
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
heart[(heart['sex']==1) & (heart['fbs']==1)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1      53    1   0       140   203    1        0      155      1      3.1
# 14     52    1   0       128   204    1        1      156      1      1.0
# 19     58    1   2       140   211    1        0      165      0      0.0
# 28     56    1   2       130   256    1        0      142      1      0.6
# 49     60    1   0       117   230    1        1      160      1      1.4
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 993    43    1   0       132   247    1        0      143      1      0.1
# 999    67    1   0       125   254    1        1      163      0      0.2
# 1003   52    1   0       108   233    1        1      147      0      0.1
# 1006   58    1   2       140   211    1        0      165      0      0.0
# 1016   65    1   3       138   282    1        0      174      0      1.4
#
#       slope  ca  thal  target
# 1         0   0     3       0
# ...

# %%
print('Sex Male(1) and Blood Suger No(0) value is 602,\nSex Male(1) And Blood Suger Yes(1) value is 111')
# Out:
# Sex Male(1) and Blood Suger No(0) value is 602,
# Sex Male(1) And Blood Suger Yes(1) value is 111
